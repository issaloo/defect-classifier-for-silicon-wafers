# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
model_df = pd.read_csv('model_dataset/labeled_processed_data.csv')
model_df['class'] = 'none'
model_df.loc[model_df['scratch'] == 1, 'class'] = 'scratch'
model_df.loc[model_df['focus_spot'] == 1, 'class'] = 'focus_spot'

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Analyze relationships through graphs

# %%
sns.countplot(x='class', data=model_df)
plt.title('Count by Class')
plt.show()

# %%
sns.barplot(x='class', y='AREA', data=model_df)
plt.title('Area by Class')
plt.show()

# %%
sns.barplot(x='class', y='AREA', data=model_df[model_df['class'] != 'none'])
plt.title('Area by Class (Less None)')
plt.show()

# %%
sns.barplot(x='class', y='LENGTH', data=model_df)
plt.title('Length by Class')
plt.show()

# %%
sns.barplot(x='class', y='NUM_PT', data=model_df)
plt.title('Number of Points by Class')
plt.show()

# %%
sns.barplot(x='class', y='DIST_FROM_CENTER', data=model_df)
plt.title('Distance from Center (mm) by Class')
plt.show()

# %%
sns.barplot(x='class', y='NUM_WAFER_PT', data=model_df)
plt.title('Number of Wafer Points by Class')
plt.show()

# %%
sns.scatterplot(x='AREA', y='LENGTH', data=model_df)
plt.title('Scatter Plot of Length vs Area')
plt.show()

# %%
sns.scatterplot(x='AREA', y='NUM_PT', data=model_df)
plt.title('Scatter Plot of Number of Points vs Area')
plt.show()

# %% [markdown]
# ## Analyze relationships by correlation matrix

# %%
#<-------20---------><-------20---------><-------20---------><-------18------->

# %%
model_df.drop(
    columns=['c_id', 'WAFER_ID', 'none', 'scratch', 'focus_spot']).corr()
# Out:
#                     NUM_PT     CENTX     CENTY  DIST_FROM_CENTER      AREA  \
# NUM_PT            1.000000  0.032952 -0.007125          0.023861 -0.042757
# CENTX             0.032952  1.000000  0.026154          0.017336 -0.017089
# CENTY            -0.007125  0.026154  1.000000         -0.037316  0.002521
# DIST_FROM_CENTER  0.023861  0.017336 -0.037316          1.000000 -0.573116
# AREA             -0.042757 -0.017089  0.002521         -0.573116  1.000000
# LENGTH           -0.064749 -0.022552 -0.001112         -0.588263  0.888250
# NUM_WAFER_PT      0.425804  0.006257 -0.010734          0.050975 -0.053757
# WAFER_CENTX       0.052553  0.288753 -0.008447         -0.027790 -0.002442
# WAFER_CENTY      -0.012778  0.002157  0.263039          0.022721 -0.037156
# NUM_CLUSTER      -0.010063  0.005939  0.028521          0.153159 -0.211861
#
#                     LENGTH  NUM_WAFER_PT  WAFER_CENTX  WAFER_CENTY  \
# NUM_PT           -0.064749      0.425804     0.052553    -0.012778
# CENTX            -0.022552      0.006257     0.288753     0.002157
# CENTY            -0.001112     -0.010734    -0.008447     0.263039
# DIST_FROM_CENTER -0.588263      0.050975    -0.027790     0.022721
# AREA              0.888250     -0.053757    -0.002442    -0.037156
# LENGTH            1.000000     -0.083227     0.003940    -0.050811
# NUM_WAFER_PT     -0.083227      1.000000     0.125677     0.035354
# WAFER_CENTX       0.003940      0.125677     1.000000    -0.124510
# WAFER_CENTY      -0.050811      0.035354    -0.124510     1.000000
# NUM_CLUSTER      -0.261562      0.210835     0.007096     0.228981
#
#                   NUM_CLUSTER
# NUM_PT              -0.010063
# CENTX                0.005939
# CENTY                0.028521
# DIST_FROM_CENTER     0.153159
# AREA                -0.211861
# LENGTH              -0.261562
# NUM_WAFER_PT         0.210835
# WAFER_CENTX          0.007096
# WAFER_CENTY          0.228981
# NUM_CLUSTER          1.000000

# %%
model_df['']

# %%
# Notes
# Imbalanced dataset, None > Focus Spot > Scratch
# Clear differences between Focus Spot and Scratch
# Scratch has smaller area and larger length, while Focus Spot has the opposite

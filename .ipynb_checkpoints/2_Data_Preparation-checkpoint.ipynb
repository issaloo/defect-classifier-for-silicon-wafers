# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import display
import os
from colorama import Fore, Style
import sys
from scipy.spatial import ConvexHull

import hdbscan
from sklearn.cluster import DBSCAN
# %matplotlib inline

# %%
data_path = glob.glob('raw_dataset/*.csv')
data_length = len(data_path)

labeled_path = glob.glob('labeled_dataset/*.csv')

# %% [markdown]
# ## Cluster points to identify areas of interest (Minimum cluster of 4)

# %%
# Initialize sample wafer and convert xy coordinates to mm
df = pd.read_csv(data_path[3])
df[['REAL_WAFER_X','REAL_WAFER_Y']] = df[['REAL_WAFER_X','REAL_WAFER_Y']]/1000

# %% [markdown]
# ### Using DBSCAN

# %%
# Find optimal EPS value
fig, ax = plt.subplots(3,3,figsize=(15,15))
ax = ax.flatten()
cmap = sns.cubehelix_palette(as_cmap=True)
for i, eps_val in enumerate(np.linspace(6,14,9)):
    clusterer = DBSCAN(eps=eps_val,min_samples=4).fit(df[['REAL_WAFER_X','REAL_WAFER_Y']])
    df['cluster_id'] = 1 + clusterer.labels_
    ax[i].scatter(df['REAL_WAFER_X'],df['REAL_WAFER_Y'],c=df['cluster_id'],s=10,cmap=cmap)
    circle = plt.Circle((0, 0), 150, color='r',fill=None)
    ax[i].add_patch(circle)
    ax[i].axis('off')
    ax[i].set_title('EPS Value: {}'.format(eps_val))
plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
plt.show()
# Outcome: 10

# %% [markdown]
# ### Using HDBSCAN

# %%
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df[['REAL_WAFER_X', 'REAL_WAFER_Y']])
df['cluster_id'] = 1 + clusterer.labels_
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df,x='REAL_WAFER_X',y='REAL_WAFER_Y',hue='cluster_id')
circle = plt.Circle((0, 0), 150, color='r',fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
plt.show()

# %% [markdown]
# ### Combining HDBSCAN and DBSCAN

# %%
df = pd.read_csv(data_path[5])
df[['REAL_WAFER_X','REAL_WAFER_Y']] = df[['REAL_WAFER_X','REAL_WAFER_Y']]/1000

# Cluster with DBSCAN
clusterer = DBSCAN(eps=10,min_samples=4).fit(df[['REAL_WAFER_X','REAL_WAFER_Y']])
df['cluster_id'] = 1 + clusterer.labels_

# Cluster DBSCAN outliers with HDBSCAN
df_sub = df.copy()
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df_sub[['REAL_WAFER_X', 'REAL_WAFER_Y']])
df_sub['cluster_id'] = 1 + clusterer.labels_
df = pd.merge(df,df_sub[['REAL_WAFER_X','REAL_WAFER_Y','cluster_id']],on=['REAL_WAFER_X','REAL_WAFER_Y'],suffixes=('','_y'))
df.loc[
    (df['cluster_id']==0)&(df['cluster_id_y'] !=0),'cluster_id'] = df.loc[
    (df['cluster_id']==0)&(df['cluster_id_y'] !=0),'cluster_id_y'] + df['cluster_id'].max()
df.drop(columns='cluster_id_y',inplace=True)

# Drop any clusters that are less than 4 samples
cluster_size = df['cluster_id'].value_counts()
df.loc[df['cluster_id'].map(cluster_size) <= 4,'cluster_id'] = 0

# Display
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df,x='REAL_WAFER_X',y='REAL_WAFER_Y',hue='cluster_id')
circle = plt.Circle((0, 0), 150, color='r',fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
plt.show()

# %% [markdown]
# ## Filter out clusters based on area

# %%
# Initialize area functions, using convex hull to determine outer coordinates
def PolygonArea(xy):
    x = xy[:,0]
    y = xy[:,1]
    x_ = x - x.mean()
    y_ = y - y.mean()
    correction = x_[-1] * y_[0] - y_[-1]* x_[0]
    main_area = np.dot(x_[:-1], y_[1:]) - np.dot(y_[:-1], x_[1:])
    polygon_area = 0.5*np.abs(main_area + correction)
    return polygon_area

def area(cluster_df):
    cluster_xy = cluster_df[['REAL_WAFER_X', 'REAL_WAFER_Y']].values
    if all(cluster_xy[:,0] == cluster_xy[1,0]) | all(cluster_xy[:,1] == cluster_xy[1,1]):
        cluster_area = 0
    else:
        hull = ConvexHull(cluster_xy)
        hull_pts = cluster_xy[hull.vertices,:]
        cluster_area = PolygonArea(hull_pts)
    return cluster_area

# %%
df = pd.read_csv(data_path[692])
df[['REAL_WAFER_X','REAL_WAFER_Y']] = df[['REAL_WAFER_X','REAL_WAFER_Y']]/1000

# Cluster with DBSCAN
clusterer = DBSCAN(eps=10,min_samples=4).fit(df[['REAL_WAFER_X','REAL_WAFER_Y']])
df['cluster_id'] = 1 + clusterer.labels_

# Cluster DBSCAN outliers with HDBSCAN
df_sub = df.copy()
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df_sub[['REAL_WAFER_X', 'REAL_WAFER_Y']])
df_sub['cluster_id'] = 1 + clusterer.labels_
df = pd.merge(df,df_sub[['REAL_WAFER_X','REAL_WAFER_Y','cluster_id']],on=['REAL_WAFER_X','REAL_WAFER_Y'],suffixes=('','_y'))
df.loc[
    (df['cluster_id']==0)&(df['cluster_id_y'] !=0),'cluster_id'] = df.loc[
    (df['cluster_id']==0)&(df['cluster_id_y'] !=0),'cluster_id_y'] + df['cluster_id'].max()
df.drop(columns='cluster_id_y',inplace=True)

# Drop any clusters that are less than 4 samples
cluster_size = df['cluster_id'].value_counts()
df.loc[df['cluster_id'].map(cluster_size) <= 4,'cluster_id'] = 0
# Display
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df,x='REAL_WAFER_X',y='REAL_WAFER_Y',hue='cluster_id')
circle = plt.Circle((0, 0), 150, color='r',fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
plt.show()

# %%
# Filter for small areas (i.e., < 0.0001 mm^2) and large areas per points (i.e., > 500 mm^2/pts)
for name, group in df.groupby('cluster_id'):
    if name != 0:
        cluster_area = area(group)
        area_per_pts = cluster_area/group.shape[1]
        if (cluster_area < 0.0005) | (area_per_pts > 250):
            df.loc[df['cluster_id'] == name,'cluster_id'] = 0
        print('Cluster ID %s' % name)
        print('Cluster Area: %f' % cluster_area)
        print('Area Per Points: %f' % area_per_pts)
        print('\n')
# Out:
# Cluster ID 3
# Cluster Area: 2543.667203
# Area Per Points: 363.381029
#
#
# Cluster ID 4
# Cluster Area: 665.289607
# Area Per Points: 95.041372

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df,x='REAL_WAFER_X',y='REAL_WAFER_Y',hue='cluster_id')
circle = plt.Circle((0, 0), 150, color='r',fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
plt.show()

# %%
# Loop through each data file and classify
# Minumum GFA is 3 points
for csv_id, csv in enumerate(data_path):
    if csv.replace('raw_dataset','labeled_dataset') not in labeled_path:      
        display.clear_output(wait=False)
        print('%d of %d' % (csv_id+1,data_length))
        df = pd.read_csv(csv)
        fig, ax = plt.subplots(figsize=(8, 8))
        sns.scatterplot(data=df,x='REAL_WAFER_X',y='REAL_WAFER_Y')
        circle = plt.Circle((0, 0), 150, color='r',fill=None)
        ax.add_patch(circle)
        plt.setp(ax, xlim=[-150,150], ylim=[-150,150])
        plt.show()
        gfa_label = input(
            "[streak, focus_spot, burp]\nExample Input: 0 2 1\nTo Exit Loop input 1111\nTo Skip input skip\n\nLabel(s): ")
        if gfa_label == 'exit':
            break
        if gfa_label != 'skip':
            gfa_label = gfa_label.split()
            df['streak'] = gfa_label[0]
            df['focus_spot'] = gfa_label[1]
            df['burp'] = gfa_label[2]

            dest = csv.replace('raw_dataset','labeled_dataset')
            df.to_csv(dest,index=False)
# Out:
# 1 of 1103
# [streak, focus_spot, burp]
# Example Input: 0 2 1
# To Exit Loop input 1111
# To Skip input skip
#
# Label(s):  1111
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-8423559e1fba> in <module>
#      24             gfa_label = gfa_label.split()
#      25             df['streak'] = gfa_label[0]
# ---> 26             df['focus_spot'] = gfa_label[1]
#      27             df['burp'] = gfa_label[2]
#      28
#
# IndexError: list index out of range

# %%
# Left off at 25. Skip to 25
# Definitely need to think about this more...  One Wafer can have multiple classifications...
# Multilabel Classification
# [0 0 0]
# [1 1 0]
# [0 1 0]
# ...
# No folders in labeled_data folder

# This should be how the program runs:
# First groups with (H?)DBSCAN, perform feature calculations (gfa area, etc.) on groups, then label based on features.

# %%
# Predict whether it is nothing, streak, focus spot, or 

# Goal: Predict whether somethings is nothing, streak, focus spot, or burp
# This is a multi-label problem (e.g., multiple classes per prediction)
# rather than a multi-class (e.g, only one class per prediction)

# Grouping points then predicting is a multi-class problem
# Predicting for gfa counts for each gfa type on the wafer is a multi-label problem

# First start with multi-class problem?

# %%
import glob
import os
import sys

import hdbscan
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from colorama import Fore, Style
from IPython import display
from scipy.spatial import ConvexHull
from sklearn.cluster import DBSCAN
# %matplotlib inline

# %%
data_path = glob.glob('raw_dataset/*.csv')
data_length = len(data_path)

labeled_path = glob.glob('labeled_dataset/*.csv')

# %% [markdown]
# ## 1. Evaluating clustering and filtering for optimal clusters

# %% [markdown]
# ## Cluster points to identify areas of interest (Minimum cluster of 4)

# %%
# Initialize sample wafer and convert xy coordinates to mm
df = pd.read_csv(data_path[3])
df.rename(columns={'REAL_WAFER_X': 'X','REAL_WAFER_Y': 'Y'}, inplace=True)
df[['X', 'Y']] = df[['X', 'Y']]/1000

# %% [markdown]
# ### Using DBSCAN

# %%
# Find optimal EPS value
fig, ax = plt.subplots(3, 3, figsize=(15,15))
ax = ax.flatten()
cmap = sns.cubehelix_palette(as_cmap=True)
for i, eps_val in enumerate(np.linspace(6, 14, 9)):
    clusterer = DBSCAN(eps=eps_val,min_samples=4).fit(df[['X', 'Y']])
    df['c_id'] = 1 + clusterer.labels_
    ax[i].scatter(df['X'], df['Y'], c=df['c_id'], s=10, cmap=cmap)
    circle = plt.Circle((0, 0), 150, color='r', fill=None)
    ax[i].add_patch(circle)
    ax[i].axis('off')
    ax[i].set_title('EPS Value: {}'.format(eps_val))
plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
plt.show()
# Outcome: 10

# %% [markdown]
# ### Using HDBSCAN

# %%
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df[['X', 'Y']])
df['c_id'] = 1 + clusterer.labels_
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df, x='X', y='Y', hue='c_id')
circle = plt.Circle((0, 0), 150, color='r', fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
plt.show()

# %% [markdown]
# ### Combining HDBSCAN and DBSCAN

# %%
df = pd.read_csv(data_path[3])
df.rename(columns={'REAL_WAFER_X': 'X', 'REAL_WAFER_Y': 'Y'}, inplace=True)
df[['X', 'Y']] = df[['X', 'Y']]/1000

# Cluster with DBSCAN
clusterer = DBSCAN(eps=10, min_samples=4).fit(df[['X', 'Y']])
df['c_id'] = 1 + clusterer.labels_

# Cluster DBSCAN outliers with HDBSCAN
df_sub = df.copy()
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df_sub[['X', 'Y']])
df_sub['c_id'] = 1 + clusterer.labels_
df = pd.merge(df, df_sub[['X', 'Y', 'c_id']], 
              on=['X', 'Y'], suffixes=('', '_y'))
df.loc[
    (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id'] = df.loc[
    (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id_y'] + df['c_id'].max()
df.drop(columns='c_id_y', inplace=True)

# Drop any clusters that are less than 4 samples
cluster_size = df['c_id'].value_counts()
df.loc[df['c_id'].map(cluster_size) <= 4,'c_id'] = 0

# Display
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df, x='X', y='Y', hue='c_id')
circle = plt.Circle((0, 0), 150, color='r', fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
plt.show()

# %% [markdown]
# ## Filter out clusters based on area

# %%
# Initialize area functions, using convex hull to determine outer coordinates
def PolygonArea(xy):
    x = xy[:, 0]
    y = xy[:, 1]
    x_ = x - x.mean()
    y_ = y - y.mean()
    correction = x_[-1]*y_[0] - y_[-1]*x_[0]
    main_area = np.dot(x_[:-1], y_[1:]) - np.dot(y_[:-1], x_[1:])
    polygon_area = 0.5*np.abs(main_area + correction)
    return polygon_area

def area(cluster_df):
    cluster_xy = cluster_df[['X', 'Y']].values
    if (all(cluster_xy[:, 0] == cluster_xy[1, 0]) 
        | all(cluster_xy[:, 1] == cluster_xy[1, 1])):
        cluster_area = 0
    else:
        hull = ConvexHull(cluster_xy)
        hull_pts = cluster_xy[hull.vertices, :]
        cluster_area = PolygonArea(hull_pts)
    return cluster_area

# %%
df = pd.read_csv(data_path[3])
df.rename(columns={'REAL_WAFER_X': 'X','REAL_WAFER_Y': 'Y'}, inplace=True)
df[['X', 'Y']] = df[['X', 'Y']]/1000

# Cluster with DBSCAN
clusterer = DBSCAN(eps=10, min_samples=4).fit(df[['X', 'Y']])
df['c_id'] = 1 + clusterer.labels_

# Cluster DBSCAN outliers with HDBSCAN
df_sub = df.copy()
clusterer = hdbscan.HDBSCAN(min_samples=4)
clusterer.fit(df_sub[['X', 'Y']])
df_sub['c_id'] = 1 + clusterer.labels_
df = pd.merge(df, df_sub[['X', 'Y', 'c_id']], 
              on=['X', 'Y'], suffixes=('', '_y'))
df.loc[
    (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id'] = df.loc[
    (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id_y'] + df['c_id'].max()
df.drop(columns='c_id_y', inplace=True)

# Drop any clusters that are less than 4 samples
cluster_size = df['c_id'].value_counts()
df.loc[df['c_id'].map(cluster_size) <= 4, 'c_id'] = 0

# Display
print('Before Filter')
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df, x='X', y='Y', hue='c_id')
circle = plt.Circle((0, 0), 150, color='r', fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
plt.show()
# Out:
# Before Filter

# %%
# Filter for small areas (<0.0001 mm^2) and large areas per points (>500 mm^2/pts)
for name, group in df.groupby('c_id'):
    if name != 0:
        cluster_area = area(group)
        area_per_pts = cluster_area/group.shape[1]
        if (cluster_area < 0.0005) | (area_per_pts > 250):
            df.loc[df['c_id'] == name, 'c_id'] = 0
        print('Cluster ID %s' % name)
        print('Cluster Area: %f' % cluster_area)
        print('Area Per Points: %f' % area_per_pts)
        print('\n')
# Out:
# Cluster ID 1
# Cluster Area: 34.454188
# Area Per Points: 4.922027
#
#
# Cluster ID 2
# Cluster Area: 0.000012
# Area Per Points: 0.000002
#
#
# Cluster ID 3
# Cluster Area: 1224.901999
# Area Per Points: 174.986000

# %%
print('After Filter')
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df, x='X', y='Y', hue='c_id')
circle = plt.Circle((0, 0), 150, color='r', fill=None)
ax.add_patch(circle)
ax.axis('off')
plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
plt.show()
# Out:
# After Filter

# %% [markdown]
# ## 2. Combine desired clustering and filtering and label all data

# %%
for csv_id, csv in enumerate(data_path):
    if csv.replace('raw_dataset', 'labeled_dataset') not in labeled_path:      
        display.clear_output(wait=False)
        print('%d of %d' % (csv_id + 1, data_length))
        df = pd.read_csv(csv)
        df.rename(columns={'REAL_WAFER_X': 'X', 'REAL_WAFER_Y': 'Y'}, inplace=True)
        df[['X', 'Y']] = df[['X', 'Y']]/1000
        
        # Cluster with DBSCAN
        clusterer = DBSCAN(eps=10, min_samples=4).fit(df[['X', 'Y']])
        df['c_id'] = 1 + clusterer.labels_

        # Cluster DBSCAN outliers with HDBSCAN
        df_sub = df.copy()
        clusterer = hdbscan.HDBSCAN(min_samples=4)
        clusterer.fit(df_sub[['X', 'Y']])
        df_sub['c_id'] = 1 + clusterer.labels_
        df = pd.merge(df, df_sub[['X', 'Y', 'c_id']], 
                      on=['X', 'Y'], suffixes=('', '_y'))
        df.loc[
            (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id'] = df.loc[
            (df['c_id'] == 0) & (df['c_id_y'] != 0), 'c_id_y'] + df['c_id'].max()
        df.drop(columns='c_id_y', inplace=True)

        # Any clusters that are less than 4 samples are not considered
        cluster_size = df['c_id'].value_counts()
        df.loc[df['c_id'].map(cluster_size) <= 4, 'c_id'] = 0
        print(df)
        break
# Out:
# 1 of 1103
#       LOT_ID  WAFER_ID WAFER_SCRIBE_ID      INSPECTION_DATE           X  \
# 0   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59 -118.944463
# 1   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59 -117.872247
# 2   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59 -117.701912
# 3   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59 -107.921980
# 4   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59 -107.618931
# 5   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  -78.083193
# 6   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  -52.325163
# 7   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  -22.928570
# 8   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59   -0.517110
# 9   H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59   38.189591
# 10  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59   50.773700
# 11  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59   50.773771
# 12  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59   72.126300
# 13  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  105.095003
# 14  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  110.199892
# 15  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  116.629173
# 16  H9212940        26    5CXZR026MVB3  2019-08-28 10:39:59  118.186157
#
#             Y  c_id
# 0   30.579171     1
# 1   30.813035     1
# 2  -33.059266     1
# 3  -32.079192     1
# 4   30.148652     1
# 5  -40.449124     0
# 6   67.542495     2
# 7   75.409507     2
# 8    2.802102     0
# 9   29.247832     2
# 10  78.988857     0
# 11  69.295293     2
# 12   3.839234     2
# 13  20.237247     2
# 14  18.486143     2
# 15   0.440118     2
# 16   0.440129     2

# %%
# # Loop through each data file and classify
# # Minumum GFA is 3 points
# for csv_id, csv in enumerate(data_path):
#     if csv.replace('raw_dataset', 'labeled_dataset') not in labeled_path:      
#         display.clear_output(wait=False)
#         print('%d of %d' % (csv_id + 1, data_length))
#         df = pd.read_csv(csv)
#         df.rename(columns={'REAL_WAFER_X': 'X', 'REAL_WAFER_Y': 'Y'}, inplace=True)
#         fig, ax = plt.subplots(figsize=(8, 8))
#         sns.scatterplot(data=df, x='X', y='Y')
#         circle = plt.Circle((0, 0), 150, color='r', fill=None)
#         ax.add_patch(circle)
#         plt.setp(ax, xlim=[-150, 150], ylim=[-150, 150])
#         plt.show()
#         gfa_label = input(
#             """[streak, focus_spot, burp]\nExample Input: 0 2 1\nTo Exit Loop input 1111\nTo Skip input skip\n\nLabel(s): """)
#         if gfa_label == 'exit':
#             break
#         if gfa_label != 'skip':
#             gfa_label = gfa_label.split()
#             df['streak'] = gfa_label[0]
#             df['focus_spot'] = gfa_label[1]
#             df['burp'] = gfa_label[2]

#             dest = csv.replace('raw_dataset', 'labeled_dataset')
#             df.to_csv(dest, index=False)
# Out:
# 1 of 1103
# [streak, focus_spot, burp]
#             Example Input: 0 2 1
# To Exit Loop input 1111
# To Skip input skip
#
# Label(s):  1111
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-83be4bf4ee84> in <module>
#      21             gfa_label = gfa_label.split()
#      22             df['streak'] = gfa_label[0]
# ---> 23             df['focus_spot'] = gfa_label[1]
#      24             df['burp'] = gfa_label[2]
#      25
#
# IndexError: list index out of range

# %%
# Left off at 25. Skip to 25
# Definitely need to think about this more...  One Wafer can have multiple classifications...
# Multilabel Classification
# [0 0 0]
# [1 1 0]
# [0 1 0]
# ...
# No folders in labeled_data folder

# This should be how the program runs:
# First groups with (H?)DBSCAN, perform feature calculations (gfa area, etc.) on groups, then label based on features.

# %%
# Predict whether it is nothing, streak, focus spot, or 

# Goal: Predict whether somethings is nothing, streak, focus spot, or burp
# This is a multi-label problem (e.g., multiple classes per prediction)
# rather than a multi-class (e.g, only one class per prediction)

# Grouping points then predicting is a multi-class problem
# Predicting for gfa counts for each gfa type on the wafer is a multi-label problem

# First start with multi-class problem?
